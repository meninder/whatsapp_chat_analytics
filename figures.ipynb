# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import fns

# %%
file_chat = 'chat_generator/chat_war_peace.txt'

# %%
df = fns.create_df(file_chat)

# %%
#df.head(100)

# %%
fig, ax = fns.person_count_bar_chart(df, 'figures/')

# %%
fig, ax = fns.person_count_word_cloud(df, 'figures/')

# %%
fig, ax = fns.rolling_count(df, 'figures/')

# %%
fig, ax = fns.sentiment_time(df, 'figures/')
